# %%
import scipy.stats as stats
import seaborn as sns
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency

# %%
fieldnames = ["Country",
              "Song Name",
              "Popularity",
              "Time Signature",
              "Duration MS",
              "Tempo",
              "Valence",
              "Liveness",
              "Instrumentalness",
              "Acousticness",
              "Speechiness",
              "Loudness",
              "Key",
              "Mode",
              "Energy",
              "Danceability",]

# %%
corr_fieldnames = [
                    'Country', 
                    'Song Name', 
                    'Popularity', 
                    'Time Signature', 
                    'Duration MS', 
                    'Tempo', 
                    'Valence', 
                    'Liveness', 
                    'Instrumentalness', 
                    'Acousticness', 'Speechiness', 
                    'Loudness', 
                    'Key', 
                    'Mode', 
                    'Energy', 
                    'Danceability', 
                    'Energy-Loudness', 
                    'Energy-Speechiness', 
                    'Energy-Valence', 
                    'Energy-Liveness', 
                    'Energy-Tempo', 
                    'Acousticness-Mode', 
                    'Acousticness-Instrumentalness', 
                    'Acousticness-Danceability', 
                    'Danceability-Valence', 
                    'Danceability-Key', 
                    'Danceability-Mode', 
                    'Danceability-Loudness', 
                    'Danceability-Time Signature', 
                    'Loudness-Speechiness', 
                    'Loudness-Valence', 
                    'Loudness-Liveness', 
                    'Loudness-Key', 
                    'Loudness-Mode', 
                    'Loudness-Tempo', 
                    'Loudness-Time Signature', 
                    'Loudness-Duration MS', 
                    'Valence-Speechiness', 
                    'Valence-Key', 
                    'Valence-Liveness', 
                    'Valence-Tempo', 
                    'Valence-Time Signature', 
                    'Speechiness-Liveness', 
                    'Speechiness-Tempo', 
                    'Liveness-Tempo', 
                    'Liveness-Key', 
                    'Instrumentalness-Mode', 
                    'Tempo-Duration MS', 
                    'Key-Mode', 
                    'Key-Duration MS', 
                    'Key-Time Signature', 
                    'Duration MS-Time Signature'
                   ]

# %%
for i in range(len(corr_fieldnames)):
    print(i,corr_fieldnames[i])
# Out:
# 0 Country
# 1 Song Name
# 2 Popularity
# 3 Time Signature
# 4 Duration MS
# 5 Tempo
# 6 Valence
# 7 Liveness
# 8 Instrumentalness
# 9 Acousticness
# 10 Speechiness
# 11 Loudness
# 12 Key
# 13 Mode
# 14 Energy
# 15 Danceability
# 16 Energy-Loudness
# 17 Energy-Speechiness
# 18 Energy-Valence
# 19 Energy-Liveness
# 20 Energy-Tempo
# 21 Acousticness-Mode
# 22 Acousticness-Instrumentalness
# 23 Acousticness-Danceability
# 24 Danceability-Valence
# 25 Danceability-Key
# 26 Danceability-Mode
# 27 Danceability-Loudness
# 28 Danceability-Time Signature
# 29 Loudness-Speechiness
# 30 Loudness-Valence
# 31 Loudness-Liveness
# 32 Loudness-Key
# 33 Loudness-Mode
# 34 Loudness-Tempo
# 35 Loudness-Time Signature
# 36 Loudness-Duration MS
# 37 Valence-Speechiness
# 38 Valence-Key
# 39 Valence-Liveness
# 40 Valence-Tempo
# 41 Valence-Time Signature
# 42 Speechiness-Liveness
# 43 Speechiness-Tempo
# 44 Liveness-Tempo
# 45 Liveness-Key
# 46 Instrumentalness-Mode
# 47 Tempo-Duration MS
# 48 Key-Mode
# 49 Key-Duration MS
# 50 Key-Time Signature
# 51 Duration MS-Time Signature

# %%
scaled_all_backup_csv_path = '../backup_csv/scaled_backup_all_song_features_csv.csv'
scaled_bangladesh_backup_csv_path = '../backup_csv/scaled_backup_bangladesh_song_features_csv.csv'
scaled_kolkata_backup_csv_path = '../backup_csv/scaled_backup_kolkata_song_features_csv.csv'

# %%
scaled_all_song_correlated_features_csv_path = '../correlated_csv/scaled_all_song_correlated_features_csv.csv'
scaled_bangladesh_song_correlated_features_csv_path = '../correlated_csv/scaled_bangladesh_song_correlated_features_csv.csv'
scaled_kolkata_song_correlated_features_csv_path = '../correlated_csv/scaled_kolkata_song_correlated_features_csv.csv'

# %%
alls = pd.read_csv(scaled_all_backup_csv_path)
bd = pd.read_csv(scaled_bangladesh_backup_csv_path)
ind = pd.read_csv(scaled_kolkata_backup_csv_path)

# %%
corr_alls = pd.read_csv(scaled_all_song_correlated_features_csv_path)
corr_bd = pd.read_csv(scaled_bangladesh_song_correlated_features_csv_path)
corr_ind = pd.read_csv(scaled_kolkata_song_correlated_features_csv_path)

# %%
def chi_testing(dataframe, index1, index2):
    fieldname1 = fieldnames[index1]
    fieldname2 = fieldnames[index2]
    dataset_table=pd.crosstab(dataframe[fieldname1],dataframe[fieldname2])
    observed = dataset_table.values
    chi2, pval, dof, expected = chi2_contingency(observed)
    return pval

# %%
arr_of_dataframes = [alls,bd,ind]
arr_of_dataframes_name = ['All Songs','Bangladeshi Songs',"Indian Songs"]
for k in range(len(arr_of_dataframes)):
    print('\n -------------------------------------------------------------------------------------------------------------\n')
    for i in range(2,len(fieldnames)-1):
        for j in range(i+1,len(fieldnames)):
            p_val = chi_testing(arr_of_dataframes[k],i,j)
            if p_val <= 0.05:
                print('(',arr_of_dataframes_name[k],')',fieldnames[i],' X ',fieldnames[j],': p value is = ',p_val,'*There is a relation*'if p_val <= 0.05 else '','\n')
# Out:
#  -------------------------------------------------------------------------------------------------------------
#
# ( All Songs ) Popularity  X  Instrumentalness : p value is =  0.014827669270530584 *There is a relation*
#
# ( All Songs ) Popularity  X  Energy : p value is =  0.03206744382200611 *There is a relation*
#
# ( All Songs ) Time Signature  X  Instrumentalness : p value is =  0.00047291334802351755 *There is a relation*
#
# ( All Songs ) Duration MS  X  Tempo : p value is =  0.017402533303208866 *There is a relation*
#
# ( All Songs ) Duration MS  X  Valence : p value is =  0.02176325038789828 *There is a relation*
#
# ( All Songs ) Duration MS  X  Liveness : p value is =  0.02457406692166406 *There is a relation*
#
# ( All Songs ) Duration MS  X  Instrumentalness : p value is =  0.04412569001170783 *There is a relation*
#
# ( All Songs ) Duration MS  X  Acousticness : p value is =  0.018960008775352373 *There is a relation*
#
# ( All Songs ) Duration MS  X  Speechiness : p value is =  0.029793330299045285 *There is a relation*
#
# ( All Songs ) Duration MS  X  Loudness : p value is =  0.017402533303209608 *There is a relation*
#
# ( All Songs ) Duration MS  X  Energy : p value is =  0.020310920711798148 *There is a relation*
#
# ( All Songs ) Duration MS  X  Danceability : p value is =  0.027288569143825096 *There is a relation*
#
# ( All Songs ) Tempo  X  Valence : p value is =  0.02176325038789828 *There is a relation*
#
# ( All Songs ) Tempo  X  Liveness : p value is =  0.024574066921663047 *There is a relation*
#
# ( All Songs ) Tempo  X  Instrumentalness : p value is =  0.04412569001170691 *There is a relation*
#
# ( All Songs ) Tempo  X  Acousticness : p value is =  0.018960008775352373 *There is a relation*
#
# ( All Songs ) Tempo  X  Speechiness : p value is =  0.029793330299046558 *There is a relation*
#
# ( All Songs ) Tempo  X  Loudness : p value is =  0.017402533303208866 *There is a relation*
#
# ( All Songs ) Tempo  X  Energy : p value is =  0.020310920711798148 *There is a relation*
#
# ( All Songs ) Tempo  X  Danceability : p value is =  0.027288569143825096 *There is a relation*
#
# ( All Songs ) Valence  X  Liveness : p value is =  0.0011831601785546007 *There is a relation*
#
# ( All Songs ) Valence  X  Acousticness : p value is =  0.007806852761199796 *There is a relation*
#
# ( All Songs ) Valence  X  Speechiness : p value is =  0.0017372377966149435 *There is a relation*
#
# ( All Songs ) Valence  X  Loudness : p value is =  0.02176325038789828 *There is a relation*
#
# ( All Songs ) Valence  X  Energy : p value is =  0.026008041249887537 *There is a relation*
#
# ( All Songs ) Valence  X  Danceability : p value is =  0.03657636213592183 *There is a relation*
#
# ( All Songs ) Liveness  X  Instrumentalness : p value is =  0.018546006272363365 *There is a relation*
#
# ( All Songs ) Liveness  X  Acousticness : p value is =  0.015081782050756151 *There is a relation*
#
# ( All Songs ) Liveness  X  Speechiness : p value is =  0.01394079440034638 *There is a relation*
#
# ( All Songs ) Liveness  X  Loudness : p value is =  0.02457406692166406 *There is a relation*
#
# ( All Songs ) Liveness  X  Energy : p value is =  0.029075297372887308 *There is a relation*
#
# ( All Songs ) Liveness  X  Danceability : p value is =  0.02483680433124528 *There is a relation*
#
# ( All Songs ) Instrumentalness  X  Acousticness : p value is =  0.0006461566196085454 *There is a relation*
#
# ( All Songs ) Instrumentalness  X  Speechiness : p value is =  0.024658577231228263 *There is a relation*
#
# ( All Songs ) Instrumentalness  X  Loudness : p value is =  0.04412569001170691 *There is a relation*
#
# ( All Songs ) Instrumentalness  X  Energy : p value is =  0.008165517348480733 *There is a relation*
#
# ( All Songs ) Instrumentalness  X  Danceability : p value is =  0.001813607616820327 *There is a relation*
#
# ( All Songs ) Acousticness  X  Speechiness : p value is =  0.01756464722444687 *There is a relation*
#
# ( All Songs ) Acousticness  X  Loudness : p value is =  0.01896000877535316 *There is a relation*
#
# ( All Songs ) Acousticness  X  Energy : p value is =  0.02389933637273795 *There is a relation*
#
# ( All Songs ) Acousticness  X  Danceability : p value is =  0.030532255866196484 *There is a relation*
#
# ( All Songs ) Speechiness  X  Loudness : p value is =  0.029793330299046558 *There is a relation*
#
# ( All Songs ) Speechiness  X  Energy : p value is =  0.012667778740949284 *There is a relation*
#
# ( All Songs ) Speechiness  X  Danceability : p value is =  0.04748923924891155 *There is a relation*
#
# ( All Songs ) Loudness  X  Energy : p value is =  0.020310920711798148 *There is a relation*
#
# ( All Songs ) Loudness  X  Danceability : p value is =  0.027288569143823948 *There is a relation*
#
# ( All Songs ) Energy  X  Danceability : p value is =  0.004616399303043545 *There is a relation*
#
#
#  -------------------------------------------------------------------------------------------------------------
#
# ( Bangladeshi Songs ) Popularity  X  Speechiness : p value is =  0.02045894113988778 *There is a relation*
#
# ( Bangladeshi Songs ) Instrumentalness  X  Danceability : p value is =  0.037761867787398574 *There is a relation*
#
# ( Bangladeshi Songs ) Speechiness  X  Danceability : p value is =  0.038731001837685665 *There is a relation*
#
# ( Bangladeshi Songs ) Key  X  Mode : p value is =  0.008360240537250421 *There is a relation*
#
#
#  -------------------------------------------------------------------------------------------------------------
#
# ( Indian Songs ) Time Signature  X  Instrumentalness : p value is =  0.0012370102023873545 *There is a relation*
#
# ( Indian Songs ) Valence  X  Speechiness : p value is =  0.02379610681947305 *There is a relation*
#
# ( Indian Songs ) Liveness  X  Instrumentalness : p value is =  0.049107002878823136 *There is a relation*
#
# ( Indian Songs ) Liveness  X  Danceability : p value is =  0.03425437979983863 *There is a relation*

# %%
def corr_chi_testing(dataframe, index1, index2):
    fieldname1 = corr_fieldnames[index1]
    fieldname2 = corr_fieldnames[index2]
    dataset_table=pd.crosstab(dataframe[fieldname1],dataframe[fieldname2])
    observed = dataset_table.values
    chi2, pval, dof, expected = chi2_contingency(observed)
    return pval

# %%
corr_arr_of_dataframes = [corr_alls,corr_bd,corr_ind]
corr_arr_of_dataframes_name = ['All Songs','Bangladeshi Songs',"Indian Songs"]
for k in range(len(corr_arr_of_dataframes)):
    print('\n -------------------------------------------------------------------------------------------------------------\n')
    for i in range(2,3):
        for j in range(i+1,len(corr_fieldnames)):
            p_val = corr_chi_testing(corr_arr_of_dataframes[k],i,j)
            if p_val <= 0.05:
                print('(',corr_arr_of_dataframes_name[k],')',corr_fieldnames[i],' X ',corr_fieldnames[j],': p value is = ',p_val,'*There is a relation*'if p_val <= 0.05 else '','\n')
# Out:
#  -------------------------------------------------------------------------------------------------------------
#
# ( All Songs ) Popularity  X  Instrumentalness : p value is =  0.014827669270530584 *There is a relation*
#
# ( All Songs ) Popularity  X  Energy : p value is =  0.03206744382200611 *There is a relation*
#
# ( All Songs ) Popularity  X  Acousticness-Mode : p value is =  0.0021168067970037336 *There is a relation*
#
# ( All Songs ) Popularity  X  Acousticness-Instrumentalness : p value is =  0.011698441775690642 *There is a relation*
#
# ( All Songs ) Popularity  X  Danceability-Mode : p value is =  0.0031791431808652023 *There is a relation*
#
# ( All Songs ) Popularity  X  Loudness-Mode : p value is =  0.0008725001193296682 *There is a relation*
#
# ( All Songs ) Popularity  X  Instrumentalness-Mode : p value is =  1.0117742190234033e-06 *There is a relation*
#
#
#  -------------------------------------------------------------------------------------------------------------
#
# ( Bangladeshi Songs ) Popularity  X  Speechiness : p value is =  0.02045894113988778 *There is a relation*
#
# ( Bangladeshi Songs ) Popularity  X  Acousticness-Mode : p value is =  0.000326592254146245 *There is a relation*
#
# ( Bangladeshi Songs ) Popularity  X  Danceability-Key : p value is =  0.031615889667868886 *There is a relation*
#
# ( Bangladeshi Songs ) Popularity  X  Danceability-Mode : p value is =  0.0009149804932285927 *There is a relation*
#
# ( Bangladeshi Songs ) Popularity  X  Loudness-Mode : p value is =  0.00013395230304990237 *There is a relation*
#
# ( Bangladeshi Songs ) Popularity  X  Instrumentalness-Mode : p value is =  0.016783598456559655 *There is a relation*
#
# ( Bangladeshi Songs ) Popularity  X  Key-Duration MS : p value is =  0.0452614203722704 *There is a relation*
#
#
#  -------------------------------------------------------------------------------------------------------------
