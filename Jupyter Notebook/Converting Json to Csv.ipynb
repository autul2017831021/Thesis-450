# %%
import csv
import os
import json
from collections import Counter
import pandas as pd

# %%
fieldnames = ["Country",
              "Song Name",
              "Popularity",
              "Time Signature",
              "Duration MS",
              "Tempo",
              "Valence",
              "Liveness",
              "Instrumentalness",
              "Acousticness",
              "Speechiness",
              "Loudness",
              "Key",
              "Mode",
              "Energy",
              "Danceability",]

# %%
def has_header(csv_path):
    try:
        with open(csv_path, 'r', encoding='utf-8') as file:
            reader = csv.reader(file)
            header = next(reader)
            return header is not None
    except StopIteration:
        return False

# %%
def generate_dictionary_for_csv(fieldnames,feature_list):
    dict = []
    obj = {}
    for i in range(len(fieldnames)):
        obj[fieldnames[i]] = feature_list[i]
    dict.append(obj)
    return dict

# %%
def create_csv(csv_path,feature_list):
    with open(csv_path, mode='a', encoding="utf-8") as file:
        writer = csv.DictWriter(file,fieldnames=fieldnames)
        if not has_header(csv_path):
            writer.writeheader()
        dict = generate_dictionary_for_csv(fieldnames,feature_list)
        writer.writerows(dict)
        file.close()

# %%
def delete_csv(csv_path='csvfile.csv'):
    if os.path.exists(csv_path):
      os.remove(csv_path)

# %%
def read_json_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
        return data

def make_features_list(json_path,csv_path):
    json_data = read_json_file(json_path)
    for obj in json_data:
        if obj['Status']['Success'] == True:
            features_list = []
            features_list.append(obj['Country'])
            features_list.append(obj['Song Name'])
            features_list.append(float(obj['Popularity']))
            features_list.append(float(obj['Features']['time_signature']))
            features_list.append(float(obj['Features']['duration_ms']))
            features_list.append(obj['Features']['tempo'])
            features_list.append(obj['Features']['valence'])
            features_list.append(obj['Features']['liveness'])
            features_list.append(obj['Features']['instrumentalness'])
            features_list.append(obj['Features']['acousticness'])
            features_list.append(obj['Features']['speechiness'])
            features_list.append(obj['Features']['loudness'])
            features_list.append(float(obj['Features']['key']))
            features_list.append(float(obj['Features']['mode']))
            features_list.append(obj['Features']['energy'])
            features_list.append(obj['Features']['danceability'])
            create_csv(csv_path,features_list)
#             for i in range(len(features_list)):
#                 print(type(features_list[i]))
#             break

# %%
bangladesh_song_features_json = 'json_data/bangladesh_song_features_json.json'
kolkata_song_features_json = 'json_data/kolkata_song_features_json.json'
all_song_features_json = 'json_data/all_song_features_json.json'

bangladesh_csv_path = 'csv_data/bangladesh_song_features_csv.csv'
kolkata_csv_path = 'csv_data/kolkata_song_features_csv.csv'
all_csv_path = 'csv_data/all_song_features_csv.csv'

delete_csv(bangladesh_csv_path)
delete_csv(kolkata_csv_path)
delete_csv(all_csv_path)

make_features_list(bangladesh_song_features_json,bangladesh_csv_path)
print("One Down")
make_features_list(kolkata_song_features_json,kolkata_csv_path)
print("Two Down")
make_features_list(all_song_features_json,all_csv_path)
# Out:
# One Down
# Two Down

# %%
import pandas as pd
data = pd.read_csv(bangladesh_csv_path)
data
# Out:
#     Country                                          Song Name  Popularity  \
# 0         1  Abar Black Album Abar Bangla Band Song Officia...        15.0
# 1         1    Abar Hashimukh - Shironamhin [Lyrics Video].wav        25.0
# 2         1  Amar Prithibi Black Album Amar Prithibi Offici...        25.0
# 3         1                Anmone - Aushomapto - Aurthohin.wav        14.0
# 4         1            Anmone 2 - Aushomapto 2 - Aurthohin.wav        38.0
# ..      ...                                                ...         ...
# 77        1  গুরু ঘর বানাইলা কি দিয়া GURU GHOR BANAILA KI ...         0.0
# 78        1  ফিরিয়ে দাও Firiye Dao - Miles Bangla Lyrics b...        37.0
# 79        1  বাবা কতদিন দেখিনা তোমায় Baba Katodin Dekhina T...        24.0
# 80        1  মেয়ে তুমি কি দুঃখ চেনো Ayub Bacchu Official Sp...        24.0
# 81        1  হাসতে দেখো Hashte Dekho Ayub Bacchu Official S...        25.0
#
#     Time Signature  Duration MS    Tempo  Valence  Liveness  Instrumentalness  \
# 0              4.0     220543.0  178.116    0.543    0.1640          0.000221
# 1              3.0     336500.0  155.853    0.302    0.2570          0.000025
# 2              4.0     251844.0  159.316    0.462    0.0998          0.000808
# 3              4.0     327912.0  164.991    0.425    0.0901          0.000015
# 4              4.0     305862.0   88.734    0.372    0.1070          0.000001
# ..             ...          ...      ...      ...       ...               ...
# 77             4.0     280778.0  115.938    0.619    0.0646          0.000000
# 78             4.0     293227.0  127.301    0.825    0.0389          0.000006
# 79             4.0     305667.0  142.024    0.284    0.3180          0.000000
# 80             4.0     353675.0   94.007    0.696    0.3380          0.000167
# 81             4.0     359799.0   98.376    0.857    0.1450          0.002800
#
#     Acousticness  Speechiness  Loudness   Key  Mode  Energy  Danceability
# 0        0.01240       0.0818    -5.232   1.0   1.0   0.890         0.323
# 1        0.16500       0.0418    -7.829   2.0   0.0   0.604         0.383
# 2        0.00369       0.0333   -12.894   1.0   1.0   0.432         0.453
# 3        0.00375       0.0312    -7.327   1.0   1.0   0.667         0.526
# 4        0.00367       0.0844    -5.781   3.0   1.0   0.897         0.313
# ..           ...          ...       ...   ...   ...     ...           ...
# 77       0.02080       0.0443    -8.142  10.0   1.0   0.632         0.824
# 78       0.08090       0.0493    -8.534   5.0   0.0   0.884         0.672
# 79       0.69800       0.0320    -6.770   3.0   1.0   0.546         0.623
# 80       0.08800       0.0267    -4.742   9.0   0.0   0.785         0.705
# 81       0.13700       0.0253    -7.692   8.0   0.0   0.678         0.611
#
# [82 rows x 16 columns]

# %%
import pandas as pd
data = pd.read_csv(kolkata_csv_path)
data
# Out:
#     Country                                          Song Name  Popularity  \
# 0         0    Amar Bhindeshi Tara - Chondrobindu (Lyrics).wav        38.0
# 1         0          Amar Priya Cafe by Moheener Ghoraguli.wav        24.0
# 2         0  Ami ek garib premik neela আমি এক গরীব প্রেমিক ...        17.0
# 3         0  Amra Bhison EkaCactus আমরা ভীষণ একা ক্যাকটাস L...         0.0
# 4         0       Aro Ekber Fossils Audio Song Rupam Islam.wav        24.0
# 5         0  Bhalo Lage - Moheener Ghoraguli II ভালোবাসি জ্...        21.0
# 6         0  Bhalo Theko - Recreated ভালো থেকো Cactuss New ...         2.0
# 7         0  Bishakto Chumbon OFFICIAL MUSIC VIDEO EESHAAN ...         5.0
# 8         0                    Bondhu Tomay - Chandrabindu.wav        31.0
# 9         0  Brishti Uh Ma with lyrics Cactus Bengali Band ...         1.0
# 10        0                        Chandrabindu Mon Lyrics.wav        33.0
# 11        0                            Chandrabindu - Juju.wav        24.0
# 12        0  Classroom by prithibi band lyrics(ক্লাসরুম -পৃ...        31.0
# 13        0  Coffee Houser Sei Addata Aaj Aar Nei Manna Dey...        27.0
# 14        0                 Darjeeling by Anjan Dutta 1994.wav        13.0
# 15        0  E bhabeo Phire Asha Jaye Chandrabindoo Audio S...        32.0
# 16        0                           Eeshaan - Bangladesh.wav         9.0
# 17        0                                Ek Notun Aazadi.wav        21.0
# 18        0       Ekla Ghor Fossils Audio Song Rupam Islam.wav        43.0
# 19        0                        Fossils - ACID!! Lyrics.wav        30.0
# 20        0                      Fossils - Bishakto Manush.wav        17.0
# 21        0                       Fossils - Nemesis Lyrics.wav        33.0
# 22        0                    Ganga by Moheener Ghoraguli.wav         6.0
# 23        0         Ghore Ferar Gaan by Moheener Ghoraguli.wav        26.0
# 24        0                     GHUM EESHAAN Album GIRGITI.wav         3.0
# 25        0                  GIRGITI EESHAAN Album GIRGITI.wav         6.0
# 26        0                                Haajar Bichhana.wav        32.0
# 27        0      Hansnuhana Fossils Rupam Islam Audio Song.wav        44.0
# 28        0  Jeremir Behala জেরেমির বেহালা Anjan Dutta Slid...         9.0
# 29        0  Jibon Chaiche Aro Besi - Lakkhichhara (Lyrics)...        24.0
# 30        0  Jokhon Dhoa Meghe -Maya (Moheener Ghoraguli Ed...        11.0
# 31        0                           KALANKANI RADHA POTA.wav        12.0
# 32        0                Kemon Achho Shohor Lakkhichhara.wav        21.0
# 33        0                            Khnoro Aamar Fossil.wav        44.0
# 34        0                         Lajja Prithibi Singles.wav        20.0
# 35        0       Lakkhichhara - Satsho Sokal [FNO S03E05].wav        13.0
# 36        0                               Maa by Fossils 3.wav        23.0
# 37        0       Mary Ann with lyrics মেরী আন Anjan Dutta.wav        15.0
# 38        0                                      Mohakaash.wav        25.0
# 39        0       Mohiner Ghoraguli (TAKE JATO TARAI DURE).wav        22.0
# 40        0                Mon - Cactus - Bangla Band Song.wav        28.0
# 41        0                             Mummy by Fossils 3.wav        11.0
# 42        0       Pakhider Sure Gaan By Moheener Ghoraguli.wav        20.0
# 43        0  Prithibita Naki Choto Hote Hote - Moheener Gho...        41.0
# 44        0    Ranjana ami aar asbo na by Anjan Dutta 1994.wav        22.0
# 45        0  Se ki firbe na ( Holud Pakhi) - Cactus - Bangl...        16.0
# 46        0  Shudhu Tumi Ele Na with lyrics শুধু তুমি এলে ন...        15.0
# 47        0            Sono Sudhijon by Moheener Ghoraguli.wav         8.0
# 48        0                                  Stobdho Jibon.wav         9.0
# 49        0                             Sundori by Eeshaan.wav         8.0
# 50        0              Tomay Dilam by Moheener Ghoraguli.wav        32.0
# 51        0  Tumi Na Thakle with lyrics Anjan Dutta & Usha ...        14.0
# 52        0       একটা ছেলে। Akta chele by sahana-(lyrics).wav        33.0
# 53        0  ধাঁধার থেকেও জটিল তুমি - মহীনের ঘোড়াগুলি (লিরি...        28.0
#
#     Time Signature  Duration MS    Tempo  Valence  Liveness  Instrumentalness  \
# 0              4.0     309870.0   99.710   0.4530    0.1000          0.038300
# 1              4.0     357016.0   92.221   0.4100    0.0678          0.000000
# 2              4.0     252000.0  126.471   0.5880    0.1200          0.000005
# 3              4.0     282880.0  171.468   0.4420    0.1600          0.000000
# 4              4.0     400510.0  136.951   0.1480    0.0777          0.000331
# 5              4.0     399766.0  143.960   0.4950    0.0921          0.000000
# 6              4.0     357324.0  127.970   0.3320    0.1320          0.000132
# 7              4.0     279119.0   97.996   0.7920    0.0477          0.000498
# 8              4.0     453644.0  114.957   0.6260    0.4800          0.000000
# 9              4.0     601907.0  172.824   0.0650    0.2650          0.000349
# 10             4.0     390147.0   79.987   0.3410    0.2130          0.000000
# 11             4.0     174613.0   97.520   0.8940    0.2800          0.000154
# 12             4.0     353359.0  140.029   0.4160    0.1040          0.000000
# 13             4.0     386853.0  122.852   0.7010    0.1210          0.003470
# 14             4.0     278933.0   89.944   0.7800    0.1210          0.000002
# 15             4.0     271152.0  100.002   0.9620    0.0317          0.000000
# 16             4.0     259240.0  129.985   0.5920    0.1610          0.000000
# 17             4.0     351770.0  112.988   0.4870    0.1030          0.000179
# 18             4.0     387319.0  138.038   0.2830    0.3270          0.000031
# 19             4.0     328204.0  134.071   0.3320    0.1420          0.000005
# 20             5.0     316266.0   86.605   0.1500    0.1120          0.000000
# 21             4.0     358715.0  113.008   0.4050    0.1000          0.000048
# 22             4.0     260651.0  149.570   0.3570    0.0452          0.000000
# 23             3.0     357356.0  120.443   0.5110    0.0992          0.000021
# 24             4.0     270865.0   98.106   0.2800    0.1090          0.000010
# 25             4.0     335805.0  188.075   0.8210    0.0592          0.000015
# 26             4.0     414629.0  136.014   0.3060    0.1460          0.000000
# 27             4.0     294323.0  133.127   0.3070    0.1050          0.000022
# 28             3.0     368718.0  142.367   0.2550    0.3350          0.000020
# 29             4.0     310048.0  133.692   0.8200    0.3130          0.008810
# 30             4.0     230009.0   93.747   0.2250    0.1280          0.000000
# 31             3.0     446893.0  134.476   0.2030    0.1120          0.000609
# 32             4.0     436168.0  131.976   0.1310    0.0874          0.002960
# 33             4.0     332403.0  140.616   0.4280    0.1510          0.000000
# 34             3.0     353379.0  144.964   0.4870    0.3810          0.000558
# 35             3.0     256654.0  149.736   0.1040    0.0928          0.016400
# 36             3.0     308168.0  138.527   0.0555    0.2970          0.000053
# 37             4.0     233920.0  167.963   0.7030    0.0456          0.000000
# 38             4.0     524848.0   80.098   0.2600    0.6550          0.000049
# 39             4.0     276977.0  110.079   0.7780    0.2150          0.000156
# 40             4.0     234084.0  192.001   0.3650    0.3260          0.014200
# 41             4.0     190826.0  130.026   0.6760    0.3850          0.000020
# 42             4.0     296151.0  131.707   0.3480    0.1270          0.000001
# 43             3.0     364383.0  153.080   0.2870    0.0552          0.000003
# 44             4.0     257547.0  102.821   0.6330    0.1240          0.000000
# 45             4.0     357587.0   89.982   0.2390    0.2920          0.000000
# 46             4.0     246813.0   97.061   0.1640    0.3710          0.000000
# 47             4.0     265457.0   81.312   0.8810    0.2220          0.000000
# 48             4.0     342845.0   97.964   0.3570    0.2180          0.001440
# 49             4.0     226117.0  105.021   0.5940    0.0539          0.000000
# 50             4.0     236617.0   93.197   0.1430    0.1020          0.000000
# 51             4.0     265360.0  125.965   0.6210    0.0562          0.000000
# 52             4.0     217013.0  139.905   0.1880    0.0807          0.000010
# 53             4.0     223087.0  137.601   0.6810    0.0849          0.000000
#
#     Acousticness  Speechiness  Loudness   Key  Mode  Energy  Danceability
# 0       0.884000       0.0437   -17.548   4.0   1.0  0.1780         0.457
# 1       0.656000       0.0376    -7.460   9.0   1.0  0.4240         0.722
# 2       0.972000       0.0438   -17.387   4.0   1.0  0.0924         0.532
# 3       0.338000       0.0454   -10.202   1.0   0.0  0.6100         0.458
# 4       0.078700       0.0341   -11.155   8.0   1.0  0.5060         0.382
# 5       0.450000       0.0332    -6.886   9.0   1.0  0.5610         0.521
# 6       0.021100       0.0335    -8.258   1.0   1.0  0.7210         0.569
# 7       0.051600       0.0348    -8.404  11.0   1.0  0.8710         0.630
# 8       0.574000       0.0249    -7.052   7.0   1.0  0.5800         0.784
# 9       0.683000       0.0308   -13.763   4.0   1.0  0.2690         0.262
# 10      0.367000       0.0249    -7.138   9.0   1.0  0.5100         0.648
# 11      0.291000       0.0402    -5.226   9.0   1.0  0.8130         0.849
# 12      0.016000       0.0264    -5.572   6.0   1.0  0.6640         0.498
# 13      0.904000       0.0315   -13.106   4.0   1.0  0.4160         0.620
# 14      0.593000       0.0293   -15.291   2.0   1.0  0.3720         0.713
# 15      0.278000       0.0443    -7.021  10.0   1.0  0.8400         0.757
# 16      0.044100       0.0266    -8.126   4.0   1.0  0.6430         0.612
# 17      0.040000       0.0511    -7.488   9.0   0.0  0.7780         0.698
# 18      0.238000       0.0307   -10.850   9.0   0.0  0.5270         0.666
# 19      0.009350       0.0838    -4.330   8.0   1.0  0.8950         0.709
# 20      0.592000       0.0376    -6.455   4.0   0.0  0.4870         0.338
# 21      0.054500       0.0399   -10.279   5.0   0.0  0.6400         0.620
# 22      0.874000       0.0293   -12.755   2.0   1.0  0.2200         0.385
# 23      0.550000       0.0337   -14.628   0.0   0.0  0.2740         0.453
# 24      0.307000       0.0255   -10.516   4.0   1.0  0.3240         0.617
# 25      0.098400       0.0598    -8.282   8.0   0.0  0.6180         0.543
# 26      0.007210       0.0466    -6.101   9.0   1.0  0.8860         0.535
# 27      0.270000       0.0548   -12.304   4.0   1.0  0.4270         0.528
# 28      0.737000       0.0316   -11.242   2.0   0.0  0.4510         0.409
# 29      0.031400       0.0283   -11.320  11.0   0.0  0.5360         0.555
# 30      0.853000       0.0319   -12.834   2.0   1.0  0.1630         0.370
# 31      0.894000       0.0316   -14.395   2.0   1.0  0.2440         0.453
# 32      0.419000       0.0291    -8.775   7.0   1.0  0.5010         0.565
# 33      0.195000       0.0434    -6.787   8.0   0.0  0.7700         0.403
# 34      0.020400       0.0461    -7.442   3.0   0.0  0.8870         0.463
# 35      0.631000       0.0388    -9.780   4.0   1.0  0.3840         0.443
# 36      0.588000       0.0291    -9.356   4.0   0.0  0.3440         0.268
# 37      0.233000       0.0551   -10.470   9.0   1.0  0.6170         0.552
# 38      0.125000       0.0323    -8.768   1.0   1.0  0.5640         0.430
# 39      0.753000       0.0276   -14.830   1.0   0.0  0.3220         0.773
# 40      0.076400       0.1550    -4.490   4.0   1.0  0.9480         0.356
# 41      0.002210       0.0732    -7.191   9.0   1.0  0.5230         0.642
# 42      0.210000       0.0284   -14.611   2.0   0.0  0.2590         0.470
# 43      0.387000       0.0328   -14.387   0.0   1.0  0.3830         0.379
# 44      0.000392       0.0489    -5.073   2.0   0.0  0.9560         0.554
# 45      0.624000       0.0257   -11.688   2.0   1.0  0.2590         0.544
# 46      0.321000       0.0268   -13.015   9.0   0.0  0.3620         0.517
# 47      0.663000       0.0507    -9.729   5.0   1.0  0.5480         0.337
# 48      0.018900       0.0310    -7.769   5.0   1.0  0.7860         0.513
# 49      0.293000       0.0321    -9.181   3.0   1.0  0.6220         0.610
# 50      0.915000       0.0288   -10.092   9.0   0.0  0.3450         0.550
# 51      0.289000       0.0528    -4.925  11.0   0.0  0.7870         0.751
# 52      0.797000       0.0401    -9.409   7.0   1.0  0.4390         0.636
# 53      0.807000       0.0355   -12.979   5.0   1.0  0.3380         0.643

# %%
import pandas as pd
data = pd.read_csv(all_csv_path)
data
# Out:
#      Country                                          Song Name  Popularity  \
# 0          1  Abar Black Album Abar Bangla Band Song Officia...        15.0
# 1          1    Abar Hashimukh - Shironamhin [Lyrics Video].wav        25.0
# 2          1  Amar Prithibi Black Album Amar Prithibi Offici...        25.0
# 3          1                Anmone - Aushomapto - Aurthohin.wav        14.0
# 4          1            Anmone 2 - Aushomapto 2 - Aurthohin.wav        38.0
# ..       ...                                                ...         ...
# 131        0                             Sundori by Eeshaan.wav         8.0
# 132        0              Tomay Dilam by Moheener Ghoraguli.wav        32.0
# 133        0  Tumi Na Thakle with lyrics Anjan Dutta & Usha ...        14.0
# 134        0       একটা ছেলে। Akta chele by sahana-(lyrics).wav        33.0
# 135        0  ধাঁধার থেকেও জটিল তুমি - মহীনের ঘোড়াগুলি (লিরি...        28.0
#
#      Time Signature  Duration MS    Tempo  Valence  Liveness  \
# 0               4.0     220543.0  178.116    0.543    0.1640
# 1               3.0     336500.0  155.853    0.302    0.2570
# 2               4.0     251844.0  159.316    0.462    0.0998
# 3               4.0     327912.0  164.991    0.425    0.0901
# 4               4.0     305862.0   88.734    0.372    0.1070
# ..              ...          ...      ...      ...       ...
# 131             4.0     226117.0  105.021    0.594    0.0539
# 132             4.0     236617.0   93.197    0.143    0.1020
# 133             4.0     265360.0  125.965    0.621    0.0562
# 134             4.0     217013.0  139.905    0.188    0.0807
# 135             4.0     223087.0  137.601    0.681    0.0849
#
#      Instrumentalness  Acousticness  Speechiness  Loudness   Key  Mode  \
# 0            0.000221       0.01240       0.0818    -5.232   1.0   1.0
# 1            0.000025       0.16500       0.0418    -7.829   2.0   0.0
# 2            0.000808       0.00369       0.0333   -12.894   1.0   1.0
# 3            0.000015       0.00375       0.0312    -7.327   1.0   1.0
# 4            0.000001       0.00367       0.0844    -5.781   3.0   1.0
# ..                ...           ...          ...       ...   ...   ...
# 131          0.000000       0.29300       0.0321    -9.181   3.0   1.0
# 132          0.000000       0.91500       0.0288   -10.092   9.0   0.0
# 133          0.000000       0.28900       0.0528    -4.925  11.0   0.0
# 134          0.000010       0.79700       0.0401    -9.409   7.0   1.0
# 135          0.000000       0.80700       0.0355   -12.979   5.0   1.0
#
#      Energy  Danceability
# 0     0.890         0.323
# 1     0.604         0.383
# 2     0.432         0.453
# 3     0.667         0.526
# 4     0.897         0.313
# ..      ...           ...
# 131   0.622         0.610
# 132   0.345         0.550
# 133   0.787         0.751
# 134   0.439         0.636
# 135   0.338         0.643
#
# [136 rows x 16 columns]

# %%
df = pd.read_csv(all_csv_path)

# Check the data type of each column
print(df.dtypes)
# Out:
# Country               int64
# Song Name            object
# Popularity          float64
# Time Signature      float64
# Duration MS         float64
# Tempo               float64
# Valence             float64
# Liveness            float64
# Instrumentalness    float64
# Acousticness        float64
# Speechiness         float64
# Loudness            float64
# Key                 float64
# Mode                float64
# Energy              float64
# Danceability        float64
# dtype: object
